# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url ='https://ekantipur.com/news'
response = requests.get(url)

soup = BeautifulSoup(response.content, 'html')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
# ...

# %%
article= soup.find_all('article')

# %%
print(len(article))
# Out:
# 30

# %%
article[0]
# Out:
# <article class="normal"><div class="teaser offset"><h2><a href="/news/2025/06/02/today-the-third-round-of-negotiations-between-the-transport-industry-and-the-government-continues-to-reach-an-agreement-52-55.html">आजै सहमति जुटाउने भन्दै यातायात व्यवसायी र सरकारबीच तेस्रो चरणको वार्ता जारी</a></h2><div class="author"><a href="https://ekantipur.com/author/author-14301">कान्तिपुर संवाददाता</a></div><p>भोलि हुने भनिए पनि यातायात व्यवसायी र सरकारबीच आजै तेस्रो चरणको वार्ता सुरु भएको छ । गृहमन्त्री रमेश लेखकको निर्देशनपछि आजै दुई पक्षबीच तेस्रो चरणको वार्ता सुरु भएको हो । </p></div><div class="image"><figure><a href="/news/2025/06/02/today-the-third-round-of-negotiations-between-the-transport-industry-and-the-government-continues-to-reach-an-agreement-52-55.html"><div class="placeholder"></div><img alt="आजै सहमति जुटाउने भन्दै यातायात व्यवसायी र सरकारबीच तेस्रो चरणको वार्ता जारी" data-src="https://assets-cdn-api.ekantipur.com/thumb.php?src=https://assets-cdn.ekantipur.com/uploads/source/ne
# ...

# %%
# 
news0= article[0].find_all('div', class_='teaser offset')
# news0
headlines=article[0].find('h2').text
body = article[0].find('p').text.replace('\xa0', ' ')
headlines
# body
# Out:
# 'आजै सहमति जुटाउने भन्दै यातायात व्यवसायी र सरकारबीच तेस्रो चरणको वार्ता जारी'

# %%
link= news0[0].find('a')['href']
full_link = url + link

full_link
# Out:
# 'https://ekantipur.com/news/news/2025/06/02/today-the-third-round-of-negotiations-between-the-transport-industry-and-the-government-continues-to-reach-an-agreement-52-55.html'

# %%
response = requests.get('https://ekantipur.com/news/2025/06/02/today-the-third-round-of-negotiations-between-the-transport-industry-and-the-government-continues-to-reach-an-agreement-52-55.html')

detailsPage = BeautifulSoup(response.content, 'html')

detailsPage
# Out:
# <!DOCTYPE html>
# ...

# %%
alldescription= detailsPage.find_all('div', class_="description current-news-block")
description_yesx= alldescription[0].find_all('p')
print(len(description_yesx))
description_yesx
# Out:
# 7
# [<p>काठमाडौँ — भोलि हुने भनिए पनि यातायात व्यवसायी र सरकारबीच आजै तेस्रो चरणको वार्ता सुरु भएको छ । गृहमन्त्री रमेश लेखकको निर्देशनपछि आजै दुई पक्षबीच तेस्रो चरणको वार्ता सुरु भएको हो ।</p>,
#  <p style="display:none;"></p>,
#  <p>सरकार र यातायात व्यवसायीबीच भएको दुई चरणको वार्ता निष्कर्षविहीन भएपछि पुनः मंगलबार बिहान साढे १० बजे बैठक बस्ने भनिएको थियो । </p>,
#  <p> ‘आजको दुई चरणको वार्तामा कुनै सहमति नभएपछि हामी भोलि बैठक बस्ने भनेर निस्किएका थियौं,’ नेपाल यातायात व्यवसायी राष्ट्रिय महासंघका अध्यक्ष विजयबहादुर स्वाँरले भने,’ गृहमन्त्रीको फोन आयो त्यसपछि हामी फेरि बैठकमा बसेका हौँ ।’ </p>,
#  <p>स्वाँरका अनुसार सरकारी वार्ता टोली बैठकहलबाट निस्किसकेको थियो भने, यातायात व्यवसायीले पनि विज्ञप्ति निकालेर भोलि पनि बन्द निरन्तर रहेको जानकारी दिने तयारीमा थिए ।‘ गृहमन्त्रीले तपाईंहरु बैठक नछाड्नुस्, म सरकारी वार्ता टोलीलाई पनि पुन: बैठकमा जानू भन्छु भन्नुभयो,’स्वाँरले भने,‘ गृहमन्त्रीले यो विषय आज नै राजनीतिक रूपमा हल गर्नुपर्छ भन्नु भएको छ ।’ </p>,
# ...

# %%
# description=[]
# for i in description_yesx:
#     description.append(i.text.replace('\xa0', ' '))
    
# description
description=[]

for i in description_yesx:
    # print(i.text.replace('\xa0', ' '))
    description=description+[i.text.replace('\xa0', ' ').strip()]
    
description = " ".join(description)    
description
# Out:
# 'काठमाडौँ — भोलि हुने भनिए पनि यातायात व्यवसायी र सरकारबीच आजै तेस्रो चरणको वार्ता सुरु भएको छ । गृहमन्त्री रमेश लेखकको निर्देशनपछि आजै दुई पक्षबीच तेस्रो चरणको वार्ता सुरु भएको हो ।  सरकार र यातायात व्यवसायीबीच भएको दुई चरणको वार्ता निष्कर्षविहीन भएपछि पुनः मंगलबार बिहान साढे १० बजे बैठक बस्ने भनिएको थियो । ‘आजको दुई चरणको वार्तामा कुनै सहमति नभएपछि हामी भोलि बैठक बस्ने भनेर निस्किएका थियौं,’ नेपाल यातायात व्यवसायी राष्ट्रिय महासंघका अध्यक्ष विजयबहादुर स्वाँरले भने,’ गृहमन्त्रीको फोन आयो त्यसपछि हामी फेरि बैठकमा बसेका हौँ ।’ स्वाँरका अनुसार सरकारी वार्ता टोली बैठकहलबाट निस्किसकेको थियो भने, यातायात व्यवसायीले पनि विज्ञप्ति निकालेर भोलि पनि बन्द निरन्तर रहेको जानकारी दिने तयारीमा थिए ।‘ गृहमन्त्रीले तपाईंहरु बैठक नछाड्नुस्, म सरकारी वार्ता टोलीलाई पनि पुन: बैठकमा जानू भन्छु भन्नुभयो,’स्वाँरले भने,‘ गृहमन्त्रीले यो विषय आज नै राजनीतिक रूपमा हल गर्नुपर्छ भन्नु भएको छ ।’ यसअघिको बैठकले ६ बुँदामा सहमति नजिक पुगे पनि मुख्य मागमा भने सहमति जुट्न सकेको थिएन । भौतिक पूर्वाधार तथा यातायात मन्
# ...

# %%
data = {
    'headlines': [],
    'body': [],
    'description': [],
}
df = pd.DataFrame(data)
df
# Out:
# Empty DataFrame
# Columns: [headlines, body, description]
# Index: []

# %%
print(headlines.text)
print(body)
print(description)
# Out:
# आजै सहमति जुटाउने भन्दै यातायात व्यवसायी र सरकारबीच तेस्रो चरणको वार्ता जारी
# भोलि हुने भनिए पनि यातायात व्यवसायी र सरकारबीच आजै तेस्रो चरणको वार्ता सुरु भएको छ । गृहमन्त्री रमेश लेखकको निर्देशनपछि आजै दुई पक्षबीच तेस्रो चरणको वार्ता सुरु भएको हो ।
# ...

# %%
df.loc[len(df)] = [headlines.text, body, description]

# %%
for i in article:
    headlines= i.find('h2')
    body = i.find('p').text
    cleanedBody = body.replace('\xa0', ' ')
    
    df.loc[len(df)] = [headlines, cleanedBody, description[0]]


df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 5
#       3     body = i.find('p').text
#       4     cleanedBody = body.replace('\xa0', ' ')
# ----> 5     df.loc[len(df)] = [headlines, cleanedBody, description[0]]
#       8 df
#
# File ~/Desktop/Python/scrapping/.venv/lib64/python3.13/site-packages/pandas/core/indexing.py:911, in _LocationIndexer.__setitem__(self, key, value)
#     908 self._has_valid_setitem_indexer(key)
#     910 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 911 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File ~/Desktop/Python/scrapping/.venv/lib64/python3.13/site-packages/pandas/core/indexing.py:1812, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1810     val = list(value.values()) if isinstance(value, dict) else value
#    1811     arr = self.obj._mgr.arrays[0]
# ...

# %%
# headlines=article[0].find('h2').text
# headlines

# %%
# body=article[0].find('p').text
# body

# %%
# clean_text = body.replace('\xa0', ' ')
# clean_text

# %%
df.to_csv('ekantipur_news_details.csv', index=False)
